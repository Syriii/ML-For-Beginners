# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# 你可以看到这个数据有 442 个项目，组成了 10 个元素的数组：
# 10个元素指的是10个特征变量，比如age、bmi、bp等
# 但是数据看起来是已经经过归一化处理
# 数据归一化：糖尿病数据集的特征数据已经过归一化处理，使得特征值均值为0，方差为1。
# X：Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of n_samples (i.e. the sum of squares of each column totals 1).
# y：Column 11 is a quantitative measure of disease progression one year after baseline
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
X = X[:, np.newaxis, 2]
print(X)

# np.newaxis用于增加数组的维度，使结果成为二维数组。
# 选择第2列数据作为新的特征矩阵X。
# Out:
# [[ 0.06169621]
#  [-0.05147406]
#  [ 0.04445121]
#  [-0.01159501]
#  [-0.03638469]
#  [-0.04069594]
#  [-0.04716281]
#  [-0.00189471]
#  [ 0.06169621]
#  [ 0.03906215]
#  [-0.08380842]
#  [ 0.01750591]
#  [-0.02884001]
#  [-0.00189471]
#  [-0.02560657]
#  [-0.01806189]
#  [ 0.04229559]
#  [ 0.01211685]
#  [-0.0105172 ]
#  [-0.01806189]
#  [-0.05686312]
#  [-0.02237314]
#  [-0.00405033]
#  [ 0.06061839]
#  [ 0.03582872]
#  [-0.01267283]
#  [-0.07734155]
#  [ 0.05954058]
#  [-0.02129532]
#  [-0.00620595]
#  [ 0.04445121]
#  [-0.06548562]
#  [ 0.12528712]
#  [-0.05039625]
#  [-0.06332999]
#  [-0.03099563]
#  [ 0.02289497]
#  [ 0.01103904]
#  [ 0.07139652]
#  [ 0.01427248]
#  [-0.00836158]
#  [-0.06764124]
#  [-0.0105172 ]
#  [-0.02345095]
#  [ 0.06816308]
#  [-0.03530688]
#  [-0.01159501]
#  [-0.0730303 ]
#  [-0.04177375]
#  [ 0.01427248]
#  [-0.00728377]
#  [ 0.0164281 ]
#  [-0.00943939]
#  [-0.01590626]
#  [ 0.0250506 ]
#  [-0.04931844]
#  [ 0.04121778]
#  [-0.06332999]
# ...

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.show()

# %%
# assignment
# target: a regression model between waist and situps
X,y = datasets.load_linnerud(return_X_y=True)
print(X.shape)
print(X[0])

# physiological - CSV containing 20 observations on 3 physiological variables:
# Weight, Waist and Pulse. 体重、腰围和脉搏
# Out:
# (20, 3)
# [  5. 162.  60.]

# %%
# exercise - CSV containing 20 observations on 3 exercise variables:
# Chins, Situps and Jumps. 引体向上、仰卧起坐和跳跃。
print(y.shape)
print(y[0])
# Out:
# (20, 3)
# [191.  36.  50.]

# %%
X = X[:, np.newaxis, 1]
y = y[:, np.newaxis, 1]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth = 3)
plt.plot()
# Out:
# []
